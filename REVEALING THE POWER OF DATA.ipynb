# %% [markdown]
# In \[1\]:
#
#     # importing libraries
#
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
# In \[2\]:
#
#     # loading the data
#
#     # Assuming 'data.csv' is the file containing our dataset
#     data = pd.read_csv('data.csv')
#
# In \[3\]:
#
#     # data exploration
#
#     # Display the first few rows of the dataset
#     data.head()
#
# Out\[3\]:
#
# |     | Unnamed: 0 | Name    | Age | Gender | Marks |
# |-----|------------|---------|-----|--------|-------|
# | 0   | 0          | Shubham | 26  | M      | 90    |
# | 1   | 1          | Bhushan | 25  | M      | 85    |
# | 2   | 2          | Aalapi  | 28  | F      | 95    |
# | 3   | 3          | Mrunal  | 24  | F      | 75    |
# | 4   | 4          | Suyog   | 28  | M      | 80    |
#
# In \[4\]:
#
#     data.tail()
#
# Out\[4\]:
#
# |     | Unnamed: 0 | Name    | Age | Gender | Marks |
# |-----|------------|---------|-----|--------|-------|
# | 0   | 0          | Shubham | 26  | M      | 90    |
# | 1   | 1          | Bhushan | 25  | M      | 85    |
# | 2   | 2          | Aalapi  | 28  | F      | 95    |
# | 3   | 3          | Mrunal  | 24  | F      | 75    |
# | 4   | 4          | Suyog   | 28  | M      | 80    |
#
# In \[5\]:
#
#     data.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 5 entries, 0 to 4
#     Data columns (total 5 columns):
#      #   Column      Non-Null Count  Dtype
#     ---  ------      --------------  -----
#      0   Unnamed: 0  5 non-null      int64
#      1   Name        5 non-null      object
#      2   Age         5 non-null      int64
#      3   Gender      5 non-null      object
#      4   Marks       5 non-null      int64
#     dtypes: int64(3), object(2)
#     memory usage: 332.0+ bytes
#
# In \[6\]:
#
#     data.describe()
#
# Out\[6\]:
#
# |       | Unnamed: 0 | Age       | Marks     |
# |-------|------------|-----------|-----------|
# | count | 5.000000   | 5.000000  | 5.000000  |
# | mean  | 2.000000   | 26.200000 | 85.000000 |
# | std   | 1.581139   | 1.788854  | 7.905694  |
# | min   | 0.000000   | 24.000000 | 75.000000 |
# | 25%   | 1.000000   | 25.000000 | 80.000000 |
# | 50%   | 2.000000   | 26.000000 | 85.000000 |
# | 75%   | 3.000000   | 28.000000 | 90.000000 |
# | max   | 4.000000   | 28.000000 | 95.000000 |
#
# In \[7\]:
#
#     data.isnull()
#
# Out\[7\]:
#
# |     | Unnamed: 0 | Name  | Age   | Gender | Marks |
# |-----|------------|-------|-------|--------|-------|
# | 0   | False      | False | False | False  | False |
# | 1   | False      | False | False | False  | False |
# | 2   | False      | False | False | False  | False |
# | 3   | False      | False | False | False  | False |
# | 4   | False      | False | False | False  | False |
#
# In \[8\]:
#
#     # data cleaning
#
#     # Handle missing values
#     data.dropna(inplace=True)
#
#     # Handle outliers
#     # Example:
#     # data = data[data['column'] < threshold]
#
# In \[12\]:
#
#     data.head(1)
#
# Out\[12\]:
#
# |     | Unnamed: 0 | Name    | Age | Gender | Marks |
# |-----|------------|---------|-----|--------|-------|
# | 0   | 0          | Shubham | 26  | M      | 90    |
#
# In \[ \]:
#
#     # data analysis
#
#     data['Name']
#
# In \[14\]:
#
#     # Perform specific analyses based on your requirements
#     # For example, you can calculate mean, median, mode, standard deviation, etc. of specific columns:
#     print("Mean of column 'Marks':", data['Age'].mean())
#
#     Mean of column 'Marks': 26.2
#
# In \[15\]:
#
#     # You can also visualize the data using matplotlib or seaborn
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
# In \[16\]:
#
#     # Example: Histogram of a numeric column
#     sns.histplot(data['Marks'], bins=20)
#     plt.title('Histogram of Numeric Column')
#     plt.xlabel('Values')
#     plt.ylabel('Frequency')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[17\]:
#
#     # 1. Line plot
#     plt.figure(figsize=(10, 6))
#     plt.plot(data['Age'], data['Marks'])
#     plt.title('Line Plot')
#     plt.xlabel('Age')
#     plt.ylabel('Marks')
#     plt.xticks(rotation=45)
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[23\]:
#
#     # 2. Scatter plot
#     plt.figure(figsize=(10, 6))
#     plt.scatter(data['Age'], data['Gender'])
#     plt.title('Age - gender distribution')
#     plt.xlabel('Age')
#     plt.ylabel('Gender')
#     plt.xticks(rotation=45)
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[24\]:
#
#     # 3. Histogram
#     plt.figure(figsize=(10, 6))
#     plt.hist(data['Age'], bins=20, edgecolor='black')
#     plt.title('Histogram')
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[25\]:
#
#     # 4. Box plot
#     plt.figure(figsize=(10, 6))
#     sns.boxplot(x=data['Name'], y=data['Marks'])
#     plt.title('Box Plot')
#     plt.xlabel('Name')
#     plt.ylabel('Marks')
#     plt.xticks(rotation=45)
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[27\]:
#
#     # 5. Bar plot
#     plt.figure(figsize=(10, 6))
#     sns.barplot(x=data['Name'], y=data['Marks'])
#     plt.title('Bar Plot')
#     plt.xlabel('Name')
#     plt.ylabel('Marks')
#     plt.xticks(rotation=45)
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[29\]:
#
#     # 6. Violin plot
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x=data['Name'], y=data['Age'])
#     plt.title('Violin Plot')
#     plt.xlabel('Name')
#     plt.ylabel('Age')
#     plt.xticks(rotation=45)
#     plt.grid(True)
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
